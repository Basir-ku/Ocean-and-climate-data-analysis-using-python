# %%
import xarray as xr

fname='2000monthly-surft-prec.nc'
ds = xr.open_dataset(fname)
q=ds.lsp
q.plot(x="longitude",y="latitude", col="time", col_wrap=4,
           cmap = "coolwarm", robust=True)

# %%
import cartopy.crs as ccrs
fg=q.plot(x="longitude",y="latitude", col="time", col_wrap=4,
     subplot_kws={"projection": ccrs.LambertConformal(
     central_longitude=0, central_latitude=50)},
     transform=ccrs.PlateCarree(), cmap = "coolwarm", robust=True)
fg.map(lambda: plt.gca().coastlines())
# Out:
# /Users/mohammadbasiruddin/opt/anaconda3/lib/python3.9/site-packages/xarray/plot/facetgrid.py:392: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/vj/2fsd02sj7rn0y103cxtdzbq80000gn/T/ipykernel_2277/1067607259.py in <module>
#       4      central_longitude=0, central_latitude=50)},
#       5      transform=ccrs.PlateCarree(), cmap = "coolwarm", robust=True)
# ----> 6 fg.map(lambda: plt.gca().coastlines())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/xarray/plot/facetgrid.py in map(self, func, *args, **kwargs)
#     621                 plt.sca(ax)
#     622                 innerargs = [data[a].to_numpy() for a in args]
# --> 623                 maybe_mappable = func(*innerargs, **kwargs)
# ...
